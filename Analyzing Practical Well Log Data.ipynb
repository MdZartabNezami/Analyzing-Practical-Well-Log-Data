# %%
import welly

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
well = welly.Well.from_las('15-9-19_SR_COMP.LAS')

# %%
type(well)
# Out:
# welly.well.Well

# %%
df = well.df()

# %%
df
# Out:
#                  AC  CALI  DEN      GR  NEU          RDEP          RMED
# DEPT
# 102.1568000000  NaN   NaN  NaN  5.3274  NaN           NaN           NaN
# 102.3092000000  NaN   NaN  NaN  5.8235  NaN           NaN           NaN
# 102.4616000000  NaN   NaN  NaN  6.5228  NaN           NaN           NaN
# 102.6140000000  NaN   NaN  NaN  7.2285  NaN           NaN           NaN
# 102.7664000000  NaN   NaN  NaN  9.5020  NaN           NaN           NaN
# ...              ..   ...  ...     ...  ...           ...           ...
# 4635.9043999983 NaN   NaN  NaN     NaN  NaN  0.7728999987  0.5977999994
# 4636.0567999983 NaN   NaN  NaN     NaN  NaN  0.8368999993  0.6256999997
# 4636.2091999983 NaN   NaN  NaN     NaN  NaN  0.8740999996  0.6887999993
# 4636.3615999983 NaN   NaN  NaN     NaN  NaN  0.9001999997  0.8901999978
# 4636.5139999983 NaN   NaN  NaN     NaN  NaN  0.9132999999  1.0362999984
#
# [29754 rows x 7 columns]

# %%
sns.heatmap(df)
# Out:
# <Axes: ylabel='DEPT'>

# %%
sns.heatmap(df.isna())
# Out:
# <Axes: ylabel='DEPT'>

# %%
well.count_curves()
# Out:
# 7

# %%
well.plot()

# %%
tracks =  ['MD', 'GR', 'CALI']

# %%
well.plot(tracks = tracks)

# %%
a = ['MD', ['GR','AC','CALI','DEN','NEU','RDEP','RMED']]

# %%
well.plot(tracks = a)
